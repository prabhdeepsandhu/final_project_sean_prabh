# %%
import pandas as pd

# %%
df = pd.read_csv("../top_30.csv")

# %%
df.reset_index(drop=True).to_html('abcd')

# %%
df.head(35)
# Out:
#     Unnamed: 0                                           Track  \
# 0         9027                                         7 rings
# 1         9026        break up with your girlfriend, i'm bored
# 2        86951                                            Wow.
# 3        66643                                       Con Calma
# 4        86953   Sunflower - Spider-Man: Into the Spider-Verse
# 5         9028                                      Without Me
# 6       107812                                         Happier
# 7         9037                                Sweet but Psycho
# 8       107810          Dancing With A Stranger (with Normani)
# 9       107875                                   Calma - Remix
# 10       66607                                    MIDDLE CHILD
# 11      138916                                         Secreto
# 12        9048  Taki Taki (with Selena Gomez, Ozuna & Cardi B)
# 13      107838                                      High Hopes
# ...
