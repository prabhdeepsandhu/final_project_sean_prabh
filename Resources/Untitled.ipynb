# %%
import pandas as pd

# %%
df = pd.read_csv("../top_30.csv")

# %%
a=[]

# %%
df.to_html('abcd')

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df.to_html("abc")

# %%
df = df.set_index("Track")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-e8b390a3eae7> in <module>
# ----> 1 df = df.set_index("Track")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['Track'] are in the columns"

# %%
df
# Out:
#                                                              Artist  \
# Track
# 7 rings                                               Ariana Grande
# break up with your girlfriend, i'm bored              Ariana Grande
# Wow.                                                    Post Malone
# Con Calma                                              Daddy Yankee
# Sunflower - Spider-Man: Into the Spider-Verse           Post Malone
# Without Me                                                   Halsey
# Happier                                                  Marshmello
# Sweet but Psycho                                            Ava Max
# Dancing With A Stranger (with Normani)                    Sam Smith
# Calma - Remix                                            Pedro Capó
# MIDDLE CHILD                                                J. Cole
# Secreto                                                    Anuel Aa
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)             DJ Snake
# ...
