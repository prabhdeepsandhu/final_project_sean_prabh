# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from scipy.sparse import csr_matrix

# %%
csv_path = 'Resources/SpotifyFeatures.csv'
df = pd.read_csv(csv_path)

df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
df.drop_duplicates()
df.dropna()
df = df.drop_duplicates(subset=['track_id'])

# %%
df['genre'].unique()
# Out:
# array(['Movie', 'R&B', 'A Capella', 'Alternative', 'Country', 'Dance',
#        'Electronic', 'Anime', 'Folk', 'Blues', 'Opera', 'Hip-Hop',
#        "Children's Music", 'Children’s Music', 'Rap', 'Indie',
#        'Classical', 'Pop', 'Reggae', 'Reggaeton', 'Jazz', 'Rock', 'Ska',
#        'Comedy', 'Soul', 'Soundtrack', 'World'], dtype=object)

# %%
repl_dict={"'":""}
df["genre"]= df["genre"].replace(repl_dict,regex=True)
repl_dict={"’":""}
df["genre"]= df["genre"].replace(repl_dict,regex=True)

# %%
df1 = df.drop(columns = ['artist_name', 'instrumentalness', 'key', 'mode', 'duration_ms', 'time_signature', 'track_id', 'loudness'])
df1.head()
# Out:
#    genre                        track_name  popularity  acousticness  \
# 0  Movie       C'est beau de faire un Show           0         0.611
# 1  Movie  Perdu d'avance (par Gad Elmaleh)           1         0.246
# 2  Movie    Don't Let Me Be Lonely Tonight           3         0.952
# 3  Movie    Dis-moi Monsieur Gordon Cooper           0         0.703
# 4  Movie                         Ouverture           4         0.950
#
#    danceability  energy  liveness  speechiness    tempo  valence
# 0         0.389   0.910    0.3460       0.0525  166.969    0.814
# 1         0.590   0.737    0.1510       0.0868  174.003    0.816
# 2         0.663   0.131    0.1030       0.0362   99.488    0.368
# 3         0.240   0.326    0.0985       0.0395  171.758    0.227
# 4         0.331   0.225    0.2020       0.0456  140.576    0.390

# %%
df2 = pd.DataFrame({'Track':df1['track_name'],
                   'Artist':df1['artist_name'],
                   'Genre':df1['genre']})
df2.to_csv("song_list.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'artist_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-fbb88839e601> in <module>
#       1 df2 = pd.DataFrame({'Track':df1['track_name'],
# ----> 2                    'Artist':df1['artist_name'],
#       3                    'Genre':df1['genre']})
#       4 df2.to_csv("song_list.csv")
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'artist_name'

# %%
df1.genre[df1.genre == 'Childrens Music'] = 1
df1.genre[df1.genre == 'Anime'] = 2
df1.genre[df1.genre == 'Comedy'] = 3
df1.genre[df1.genre == 'Soundtrack'] = 4
df1.genre[df1.genre == 'Movie'] = 5
df1.genre[df1.genre == 'Pop'] = 6
df1.genre[df1.genre == 'R&B'] = 7
df1.genre[df1.genre == 'Hip-Hop'] = 8
df1.genre[df1.genre == 'Rap'] = 9
df1.genre[df1.genre == 'Reggae'] = 10
df1.genre[df1.genre == 'Reggaeton'] = 11
df1.genre[df1.genre == 'Ska'] = 12
df1.genre[df1.genre == 'Soul'] = 13
df1.genre[df1.genre == 'Blues'] = 14
df1.genre[df1.genre == 'Rock'] = 15
df1.genre[df1.genre == 'Folk'] = 16
df1.genre[df1.genre == 'Country'] = 17
df1.genre[df1.genre == 'Alternative'] = 18
df1.genre[df1.genre == 'Indie'] = 19
df1.genre[df1.genre == 'Electronic'] = 20
df1.genre[df1.genre == 'Dance'] = 21
df1.genre[df1.genre == 'World'] = 22
df1.genre[df1.genre == 'Opera'] = 23
df1.genre[df1.genre == 'A Capella'] = 24
df1.genre[df1.genre == 'Jazz'] = 25
df1.genre[df1.genre == 'Classical'] = 26
# Out:
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1 = df1.set_index('track_name')
df1.head()
# Out:
#                                  genre  popularity  acousticness  \
# track_name
# C'est beau de faire un Show          5           0         0.611
# Perdu d'avance (par Gad Elmaleh)     5           1         0.246
# Don't Let Me Be Lonely Tonight       5           3         0.952
# Dis-moi Monsieur Gordon Cooper       5           0         0.703
# Ouverture                            5           4         0.950
#
#                                   danceability  energy  liveness  speechiness  \
# track_name
# C'est beau de faire un Show              0.389   0.910    0.3460       0.0525
# Perdu d'avance (par Gad Elmaleh)         0.590   0.737    0.1510       0.0868
# Don't Let Me Be Lonely Tonight           0.663   0.131    0.1030       0.0362
# Dis-moi Monsieur Gordon Cooper           0.240   0.326    0.0985       0.0395
# Ouverture                                0.331   0.225    0.2020       0.0456
#
#                                     tempo  valence
# track_name
# C'est beau de faire un Show       166.969    0.814
# Perdu d'avance (par Gad Elmaleh)  174.003    0.816
# Don't Let Me Be Lonely Tonight     99.488    0.368
# Dis-moi Monsieur Gordon Cooper    171.758    0.227
# Ouverture                         140.576    0.390

# %%
df1['genre'] = df1['genre'].astype(int)

# %%
df.to_json('file.json', orient = 'split', compression = 'infer', index = 'true')

# %%
model_knn = NearestNeighbors(algorithm= 'kd_tree',n_neighbors= 4)

# %%
mat_songs = csr_matrix(df1.values)

# %%
model_knn.fit(mat_songs)
# Out:
# C:\Users\User\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\neighbors\_base.py:462: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# NearestNeighbors(algorithm='kd_tree', n_neighbors=4)

# %%
def recommend(idx, model, number_of_recommendations= 7):
    query = df1.loc[idx].to_numpy().reshape(1,-1)
    print('Searching for recommendations...')
    distances, indices = model.kneighbors(query,n_neighbors = number_of_recommendations)
    indices=indices.flatten()
    for i in indices:
        print(i)
        print(df[['track_name','artist_name']].iloc[i])
#         .where(df['track_name']!=idx).dropna()

# %%
name = input('Enter song title: ')
print('Search results: ')
print(df[['artist_name','track_name']].where(df['track_name'] == name).dropna())

ind = int(input('Enter the index value of the required song: '))
idx = df['track_name'].loc[ind]

song = df['track_name'].loc[ind]
artists = df['artist_name'].loc[ind]

print('Song selected is ', song, 'by', artists)


nor = int(input('Enter number of recommendations: '))

recommend(idx, model_knn, nor)
# Out:
# Enter song title:
# Search results:
# Empty DataFrame
# Columns: [artist_name, track_name]
# Index: []
# Enter the index value of the required song: 9037
# Song selected is  Sweet but Psycho by Ava Max
# Enter number of recommendations: 5
# Searching for recommendations...
# 8987
# track_name     Sweet but Psycho
# artist_name             Ava Max
# Name: 9037, dtype: object
# 8978
# track_name     Without Me
# artist_name        Halsey
# Name: 9028, dtype: object
# 8992
# track_name             Sucker
# artist_name    Jonas Brothers
# Name: 9042, dtype: object
# 8983
# track_name          bad idea
# artist_name    Ariana Grande
# Name: 9033, dtype: object
# 8991
# track_name        in my head
# artist_name    Ariana Grande
# Name: 9041, dtype: object

# %%
x = df.drop(columns = ['instrumentalness', 'duration_ms', 'time_signature', 'track_id', 'loudness', 'acousticness', 'danceability', 'energy', 'liveness', 'speechiness', 'valence'])
x['tempo'] = x['tempo'].round(0)
x['tempo'] = x['tempo'].astype(int)
x= x.sort_values(by='popularity', ascending = False).head(30)

# %%
x.drop(columns = ['popularity'], inplace =True)
x = x[['track_name', 'artist_name', 'genre', 'key', 'mode', 'tempo']]
x.head()
# Out:
#                                           track_name    artist_name    genre  \
# 9027                                         7 rings  Ariana Grande    Dance
# 9026        break up with your girlfriend, i'm bored  Ariana Grande    Dance
# 86951                                           Wow.    Post Malone      Rap
# 66643                                      Con Calma   Daddy Yankee  Hip-Hop
# 86953  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone      Rap
#
#       key   mode  tempo
# 9027   C#  Minor     70
# 9026    F  Minor    170
# 86951   B  Minor    100
# 66643  G#  Minor     94
# 86953   D  Major     90

# %%
x2 = x.rename(columns = {'track_name': 'Track', 'artist_name':'Artist', 'genre':'Genre', 'key':'Key', 'mode':'Mode', 'tempo':'Tempo'})

# %%
x2.head(30).to_csv("top_30.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-19-2bb6d7aefc7b> in <module>
# ----> 1 x2.head(30).to_csv("top_30.csv")
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'top_30.csv'

# %%
df.loc[df['artist_name'] == 'Eminem']
# Out:
#          genre artist_name                                track_name  \
# 66645  Hip-Hop      Eminem            Lucky You (feat. Joyner Lucas)
# 66670  Hip-Hop      Eminem                          'Till I Collapse
# 66677  Hip-Hop      Eminem                                  Killshot
# 66701  Hip-Hop      Eminem  Lose Yourself - From "8 Mile" Soundtrack
# 66723  Hip-Hop      Eminem     Venom - Music From The Motion Picture
# ...        ...         ...                                       ...
# 91994  Hip-Hop      Eminem                            Curtains Close
# 92052  Hip-Hop      Eminem                         Hell Breaks Loose
# 92170  Hip-Hop      Eminem                              Buffalo Bill
# 92414  Hip-Hop      Eminem       Just Don't Give A Fuck - A Cappella
# 92716  Hip-Hop      Eminem                               Underground
#
#                      track_id  popularity  acousticness  danceability  \
# 66645  60SdxE8apGAxMiRrpbmLY0          86       0.06270         0.876
# 66670  4xkOaSrkexMciUUogZKVTS          85       0.07570         0.572
# 66677  1jo3TwNGCXfNdB5uba3ZVv          82       0.09890         0.892
# 66701  5Z01UMMf7V1o0MzF86s6WJ          81       0.00704         0.698
# 66723  2SL6oP2YAEQbqsrkOzRGO4          82       0.01930         0.749
# ...                       ...         ...           ...           ...
# 91994  51LeDAMy6nWqKdjVo7jK4j          52       0.63600         0.661
# 92052  0FXfAepEmqVCMnvOpb8Hoj          52       0.12300         0.685
# 92170  3lSQAn6cmWfYfwuTJry44m          52       0.02580         0.696
# 92414  64WSrtBF6R2Sdi4peJKOsp          49       0.46400         0.634
# 92716  4jpi8FljkAwKFb4ljWuar6          52       0.13500         0.631
#
#        duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 66645       244679   0.786          0.000000  A#    0.1270    -4.884  Minor
# 66670       297893   0.853          0.000000  C#    0.0798    -3.203  Major
# 66677       253580   0.651          0.000000   C    0.3710    -8.645  Minor
# 66701       326467   0.732          0.000647   D    0.3590    -4.522  Major
# 66723       269554   0.794          0.000000   C    0.5430    -5.063  Major
# ...            ...     ...               ...  ..       ...       ...    ...
# 91994        60667   0.425          0.000126   B    0.3410   -20.377  Major
# 92052       244160   0.884          0.000000  F#    0.1050    -3.072  Major
# 92170       236840   0.885          0.000000  A#    0.2470    -3.804  Minor
# 92414       215213   0.476          0.000000   G    0.1350    -9.517  Major
# 92716       371453   0.798          0.000000  G#    0.5630    -3.473  Major
#
#        speechiness    tempo time_signature  valence
# 66645        0.306  153.068            4/4   0.5750
# 66670        0.217  171.297            4/4   0.1020
# 66677        0.378  105.814            4/4   0.5990
# 66701        0.266  171.431            4/4   0.0689
# 66723        0.064  135.959            4/4   0.4600
# ...            ...      ...            ...      ...
# 91994        0.552   96.182            3/4   0.6180
# 92052        0.188   79.903            4/4   0.9020
# 92170        0.348  175.912            4/4   0.7080
# 92414        0.556   81.315            4/4   0.8140
# 92716        0.394  107.235            4/4   0.5280
#
# [172 rows x 18 columns]

# %%
print(df.iloc[78445])
# Out:
# genre                                  Rap
# artist_name                    Post Malone
# track_name                            Wow.
# track_id            6MWtB6iiXyIwun0YzU6DFP
# popularity                              99
# acousticness                         0.163
# danceability                         0.833
# duration_ms                         149520
# energy                               0.539
# instrumentalness                   2.1e-06
# key                                      B
# liveness                             0.101
# loudness                            -7.399
# mode                                 Minor
# speechiness                          0.178
# tempo                               99.947
# time_signature                         4/4
# valence                              0.385
# Name: 86951, dtype: object
